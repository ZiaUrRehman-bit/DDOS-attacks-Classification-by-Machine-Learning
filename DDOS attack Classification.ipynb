# %% [markdown]
# ### Introduction
#
# Distributed Denial of Service (DDoS) attacks are significant threats to the stability and reliability of online services. Detecting and mitigating these attacks is crucial to maintaining the integrity of networks and services. This project focuses on classifying DDoS attacks using various machine learning models. The dataset used for this project is the IDS 2017 dataset, which is publicly available and provides a comprehensive set of features for detecting DDoS attacks.
#
# The project involves several key steps: data preprocessing, exploration, splitting, model training, evaluation, and comparison. Each step is crucial to building an effective DDoS detection model. We employ multiple machine learning algorithms, including Random Forest, Logistic Regression, and Neural Networks, to classify the attacks and evaluate their performance using various metrics.

# %% [markdown]
# ### Table of Contents
#
# 1. **Importing Libraries**
# 2. **Data Pre-processing**
# 3. **Data Exploring**
# 4. **Data Splitting**
# 5. **Model Training**
#    - Random Forest
#    - Logistic Regression
#    - Neural Network
# 6. **Model Evaluation**
#    - Accuracy
#    - F1 Score
#    - Recall
#    - Precision
#    - Confusion Matrix
# 7. **Model Comparison**

# %% [markdown]
# # 01. Dataset Link
#
# Dataset link to download: Dataset is publicly available
# at http://www.unb.ca/cic/datasets/IDS2017.html

# %% [markdown]
# # 02. Import Libraries

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 03 Read the Data File

# %%
df = pd.read_csv("DDos.csv")

# %% [markdown]
# # 04. Data Preprocessing

# %% [markdown]
# ### 4.1 Display first 5 entries of dataset

# %%
df.head()
# Out:
#     Destination Port   Flow Duration   Total Fwd Packets  \
# 0              54865               3                   2
# 1              55054             109                   1
# 2              55055              52                   1
# 3              46236              34                   1
# 4              54863               3                   2
#
#     Total Backward Packets  Total Length of Fwd Packets  \
# 0                        0                           12
# 1                        1                            6
# 2                        1                            6
# 3                        1                            6
# 4                        0                           12
#
#     Total Length of Bwd Packets   Fwd Packet Length Max  \
# 0                             0                       6
# 1                             6                       6
# 2                             6                       6
# ...

# %% [markdown]
# ### 4.2 Removing the spaces before the clolumn names

# %%
df.columns = df.columns.str.strip()
df.head(2)
# Out:
#    Destination Port  Flow Duration  Total Fwd Packets  Total Backward Packets  \
# 0             54865              3                  2                       0
# 1             55054            109                  1                       1
#
#    Total Length of Fwd Packets  Total Length of Bwd Packets  \
# 0                           12                            0
# 1                            6                            6
#
#    Fwd Packet Length Max  Fwd Packet Length Min  Fwd Packet Length Mean  \
# 0                      6                      6                     6.0
# 1                      6                      6                     6.0
#
#    Fwd Packet Length Std  ...  min_seg_size_forward  Active Mean  Active Std  \
# 0                    0.0  ...                  20.0          0.0         0.0
# 1                    0.0  ...                  20.0          0.0         0.0
#
#    Active Max  Active Min  Idle Mean  Idle Std  Idle Max  Idle Min   Label
# ...

# %% [markdown]
# ### 4.3 Finding the Unique Values in target Variable

# %%
df.loc[:, 'Label'].unique()
# Out:
# array(['BENIGN', 'DDoS', nan], dtype=object)

# %% [markdown]
# we need to remove thoes record whoes Label value is nan

# %% [markdown]
# ### 4.4 Checking the Null values in the dataset

# %%
df.isna().sum()
# Out:
# Destination Port               0
# Flow Duration                  0
# Total Fwd Packets              0
# Total Backward Packets         0
# Total Length of Fwd Packets    0
#                               ..
# Idle Mean                      1
# Idle Std                       1
# Idle Max                       1
# Idle Min                       1
# Label                          1
# Length: 79, dtype: int64

# %%
missingValues = df.isna().sum()
missingValues.sum()
# Out:
# 47

# %%
plt.figure(1, figsize=(8, 5))
plt.hist(df.isna().sum())
plt.xticks([0, 1], labels=["Not Null = 0", "Null = 1"])
plt.title("Columns with Null Values")

plt.show()

plt.figure(2, figsize=(14, 5))
missingValues.plot(kind = "bar")
plt.title("Columns with Null Values")

plt.show()

# %% [markdown]
# This shows that aroun 33 columns which does not have any null value and around 50 columns which have null values

# %% [markdown]
# ### 4.5 Remove the Null Values

# %%
DDosData = df.copy()
DDosData.head(2)
# Out:
#    Destination Port  Flow Duration  Total Fwd Packets  Total Backward Packets  \
# 0             54865              3                  2                       0
# 1             55054            109                  1                       1
#
#    Total Length of Fwd Packets  Total Length of Bwd Packets  \
# 0                           12                            0
# 1                            6                            6
#
#    Fwd Packet Length Max  Fwd Packet Length Min  Fwd Packet Length Mean  \
# 0                      6                      6                     6.0
# 1                      6                      6                     6.0
#
#    Fwd Packet Length Std  ...  min_seg_size_forward  Active Mean  Active Std  \
# 0                    0.0  ...                  20.0          0.0         0.0
# 1                    0.0  ...                  20.0          0.0         0.0
#
#    Active Max  Active Min  Idle Mean  Idle Std  Idle Max  Idle Min   Label
# ...

# %%
DDosData.describe()
# Out:
#        Destination Port  Flow Duration  Total Fwd Packets  \
# count      66237.000000   6.623700e+04       66237.000000
# mean        6454.605553   1.388736e+07           5.180262
# std        16710.894455   2.815843e+07          16.873659
# min            0.000000   0.000000e+00           1.000000
# 25%           80.000000   4.995600e+04           2.000000
# 50%           80.000000   9.949050e+05           3.000000
# 75%           80.000000   7.639831e+06           5.000000
# max        61538.000000   1.199983e+08        1681.000000
#
#        Total Backward Packets  Total Length of Fwd Packets  \
# count            66237.000000                 66237.000000
# mean                 5.119223                   695.622567
# std                 23.797124                  3230.046907
# min                  0.000000                     0.000000
# 25%                  1.000000                    26.000000
# 50%                  4.000000                    30.000000
# ...

# %%
DDosData = DDosData.dropna()
DDosData.describe()
# Out:
#        Destination Port  Flow Duration  Total Fwd Packets  \
# count      66236.000000   6.623600e+04       66236.000000
# mean        6454.701794   1.388757e+07           5.180295
# std        16711.002247   2.815859e+07          16.873784
# min            0.000000   0.000000e+00           1.000000
# 25%           80.000000   4.995450e+04           2.000000
# 50%           80.000000   9.949430e+05           3.000000
# 75%           80.000000   7.640073e+06           5.000000
# max        61538.000000   1.199983e+08        1681.000000
#
#        Total Backward Packets  Total Length of Fwd Packets  \
# count            66236.000000                 66236.000000
# mean                 5.119225                   695.632677
# std                 23.797303                  3230.070242
# min                  0.000000                     0.000000
# 25%                  1.000000                    26.000000
# 50%                  4.000000                    30.000000
# ...

# %%
plt.figure(1, figsize=(8, 5))
plt.hist(DDosData.isna().sum())
plt.xticks([0, 1], labels=["Not Null = 0", "Null = 1"])
plt.title("Columns with Null Values")

plt.show()

# %% [markdown]
# ### 4.6 Check if there is `inf` value in the dataset and replace with `Nan`

# %%
pd.set_option('use_inf_as_na', True)
nullValues = DDosData.isnull().sum()
nullValues
# Out:
# C:\Users\Muhammad Nouman\AppData\Local\Temp\ipykernel_19232\764430158.py:1: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   pd.set_option('use_inf_as_na', True)
# Destination Port               0
# Flow Duration                  0
# Total Fwd Packets              0
# Total Backward Packets         0
# Total Length of Fwd Packets    0
#                               ..
# Idle Mean                      0
# Idle Std                       0
# Idle Max                       0
# Idle Min                       0
# Label                          0
# Length: 79, dtype: int64

# %% [markdown]
# ### 4.7 Encoding the Values of Target Variable

# %%
DDosData['Label'][0:10]
# Out:
# 0    BENIGN
# 1    BENIGN
# 2    BENIGN
# 3    BENIGN
# 4    BENIGN
# 5    BENIGN
# 6    BENIGN
# 7    BENIGN
# 8    BENIGN
# 9    BENIGN
# Name: Label, dtype: object

# %%
DDosData.dtypes=='object'
# Out:
# Destination Port               False
# Flow Duration                  False
# Total Fwd Packets              False
# Total Backward Packets         False
# Total Length of Fwd Packets    False
#                                ...
# Idle Mean                      False
# Idle Std                       False
# Idle Max                       False
# Idle Min                       False
# Label                           True
# Length: 79, dtype: bool

# %%
DDosData['Label'] = DDosData['Label'].map({'BENIGN':0, 'DDoS':1})
DDosData.dtypes=='object'
# Out:
# Destination Port               False
# Flow Duration                  False
# Total Fwd Packets              False
# Total Backward Packets         False
# Total Length of Fwd Packets    False
#                                ...
# Idle Mean                      False
# Idle Std                       False
# Idle Max                       False
# Idle Min                       False
# Label                          False
# Length: 79, dtype: bool

# %%
DDosData['Label']
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 66231    1
# 66232    1
# 66233    1
# 66234    1
# 66235    1
# Name: Label, Length: 66236, dtype: int64
